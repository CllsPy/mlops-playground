# %% [markdown]
# ## mlflow tracking server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check localhost connection")


with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("krish", 2)
# Out:
# 🏃 View run rambunctious-pug-456 at: http://127.0.0.1:5000/#/experiments/491416624726471500/runs/22842ba1216d448bad78722510bd81ca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/491416624726471500

# %%
mlflow.set_experiment("Check localhost connection")


with mlflow.start_run():
    mlflow.log_metric("test1", 1)
    mlflow.log_metric("krish2", 2)
# Out:
# 🏃 View run angry-snipe-236 at: http://127.0.0.1:5000/#/experiments/491416624726471500/runs/4dcdba1799eb4282a28b80b74d9fce02
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/491416624726471500
